# %%
import pandas as pd
import jieba

# %%
# 1. 读数据

data = pd.read_csv(r'D:\jupyter\双十一淘宝美妆数据分析\双十一淘宝美妆数据.csv')
data.head()
# Out:
#   update_time            id                                  title  price  \
# 0  2023/11/14  A18164178225    CHANDO/自然堂 雪域精粹纯粹滋润霜50g 补水保湿 滋润水润面霜  139.0
# 1  2023/11/14  A18177105952   CHANDO/自然堂凝时鲜颜肌活乳液120ML 淡化细纹补水滋润专柜正品  194.0
# 2  2023/11/14  A18177226992   CHANDO/自然堂活泉保湿修护精华水（滋润型135ml 补水控油爽肤水   99.0
# 3  2023/11/14  A18178033846  CHANDO/自然堂 男士劲爽控油洁面膏 100g 深层清洁  男士洗面奶   38.0
# 4  2023/11/14  A18178045259     CHANDO/自然堂雪域精粹纯粹滋润霜（清爽型）50g补水保湿滋润霜  139.0
#
#    sale_count  comment_count   店名
# 0     26719.0         2704.0  自然堂
# 1      8122.0         1492.0  自然堂
# 2     12668.0          589.0  自然堂
# 3     25805.0         4287.0  自然堂
# 4      5196.0          618.0  自然堂

# %%
# 2. 数据清洗
#      重复值， 缺失值（众数）
#      要把产品名 对应成 主类别 + 子类别 （中文分词（jieba）， 根据配置字符串，把分词结果对应成 主类别 + 子类别）
duplicate_rows = data.duplicated(subset='id', keep=False)
duplicate_data = data[duplicate_rows]
print('重复数据条数：',duplicate_data.shape)


#2. 删重复   drop
# Out:
# 重复数据条数： (27549, 7)
